# %%
# !pip install h2o 
# !pip install autokeras
# !pip install mlbox 
# !pip install sklearn
# !pip install tensorflow
# Out:
# Running cells with 'c:\Users\beu.oseias_ifood\AppData\Local\Microsoft\WindowsApps\python3.10.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/beu.oseias_ifood/AppData/Local/Microsoft/WindowsApps/python3.10.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # H2O

# %%
import pandas as pd
import h2o
from h2o.automl import H2OAutoML

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.18" 2023-01-17; OpenJDK Runtime Environment (build 11.0.18+10-post-Ubuntu-0ubuntu120.04.1); OpenJDK 64-Bit Server VM (build 11.0.18+10-post-Ubuntu-0ubuntu120.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.10/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpmubio8oj
#   JVM stdout: /tmp/tmpmubio8oj/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpmubio8oj/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         07 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.40.0.4
# H2O_cluster_version_age:    6 days
# H2O_cluster_name:           H2O_from_python_unknownUser_2abmtg
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.172 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.10.11 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
imp = pd.read_csv('/content/Churn_treino.csv',';')
# Out:
# <ipython-input-17-2697c6df4ba3>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   imp = pd.read_csv('/content/Churn_treino.csv',';')

# %%
imp = h2o.H2OFrame(imp)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
treino, teste = imp.split_frame(ratios=[0.7])

# %%
print(imp)
# Out:
#   CreditScore  Geography    Gender      Age    Tenure      Balance    NumOfProducts    HasCrCard    IsActiveMember    EstimatedSalary    Exited
#           619  France       Female       42         2  0                          1            1                 1        1.01349e+07         1
#           608  Spain        Female       41         1  8.38079e+06                1            0                 1        1.12543e+07         0
#           502  France       Female       42         8  1.59661e+06                3            1                 0        1.13932e+07         1
#           699  France       Female       39         1  0                          2            0                 0        9.38266e+06         0
#           850  Spain        Female       43         2  1.25511e+07                1            1                 1   790841                   0
#           645  Spain        Male         44         8  1.13756e+07                2            1                 0        1.49757e+07         1
#           822  France       Male         50         7  0                          2            1                 1   100628                   0
#           376  Germany      Female       29         4  1.15047e+07                4            1                 0        1.19347e+07         1
#           501  France       Male         44         4  1.42051e+07                2            0                 1   749405                   0
#           684  France       Male         27         2  1.34604e+07                1            1                 1        7.17257e+06         0
# [10000 rows x 11 columns]

# %%
treino['Exited'] = treino['Exited'].asfactor()

# %%
teste['Exited'] = teste['Exited'].asfactor()

# %%
modelo = H2OAutoML(max_runtime_secs=60)

# %%
modelo.train(y='Exited',training_frame=treino)
# Out:
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_1_20230504_124830
#
#
# Model Summary for Stacked Ensemble:
# key                                   value
# ------------------------------------  ----------------
# Stacking strategy                     cross_validation
# Number of base models (used / total)  7/8
# # GBM base models (used / total)      3/4
# # XGBoost base models (used / total)  2/2
# # DRF base models (used / total)      1/1
# # GLM base models (used / total)      1/1
# Metalearner algorithm                 GLM
# Metalearner fold assignment scheme    Random
# Metalearner nfolds                    5
# Metalearner fold_column
# Custom metalearner hyperparameters    None
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.07750978107104739
# RMSE: 0.27840578490945084
# LogLoss: 0.26227430576092553
# AUC: 0.9364485968535806
# AUCPR: 0.8372566457267344
# Gini: 0.8728971937071612
# Null degrees of freedom: 6983
# Residual degrees of freedom: 6976
# Null deviance: 7150.654479624887
# Residual deviance: 3663.4475028686074
# AIC: 3679.4475028686074
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.31420289985325683
#        0     1     Error    Rate
# -----  ----  ----  -------  --------------
# 0      5117  411   0.0743   (411.0/5528.0)
# 1      364   1092  0.25     (364.0/1456.0)
# Total  5481  1503  0.111    (775.0/6984.0)
#
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0
# GBM_4_AutoML_1_20230504_124830                           0.842795   0.35963   0.6751                  0.240657  0.330862  0.10947
# XGBoost_1_AutoML_1_20230504_124830                       0.841384   0.365907  0.665909                0.24685   0.334096  0.11162
# XGBoost_2_AutoML_1_20230504_124830                       0.841175   0.367671  0.662948                0.242468  0.335483  0.112549
# [15 rows x 7 columns]

# %%
teste = pd.read_csv('/content/Churn_prever.csv',sep=';')
teste = h2o.H2OFrame(teste)
prever = modelo.leader.predict(teste)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%

# %%
prever = prever.as_data_frame(prever)

# %%
prever
# Out:
#    predict        p0        p1
# 0        0  0.939193  0.060807
# 1        0  0.951980  0.048020
# 2        1  0.024971  0.975029
# 3        0  0.976345  0.023655
# 4        0  0.908688  0.091312
# 5        0  0.880946  0.119054
# 6        0  0.735920  0.264080
# 7        0  0.879685  0.120315
# 8        0  0.880101  0.119899

# %% [markdown]
# # AutoKeras

# %%
import autokeras as ak
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
imp = pd.read_csv('/content/Churn_treino.csv',sep=';')

# %%
X = imp.iloc[:,0:10]

# %%
y =  imp.iloc[:,10]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
modelo = ak.StructuredDataClassifier(max_trials=10)
modelo.fit(x=X_train, y = y_train, epochs=100)
# Out:
# Trial 10 Complete [00h 00m 33s]
# val_accuracy: 0.7997075915336609
#
# Best val_accuracy So Far: 0.8494151830673218
# Total elapsed time: 00h 06m 41s
# Epoch 1/100
# 219/219 [==============================] - 2s 4ms/step - loss: 0.4546 - accuracy: 0.8094
# Epoch 2/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4062 - accuracy: 0.8270
# Epoch 3/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4024 - accuracy: 0.8264
# Epoch 4/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4004 - accuracy: 0.8309
# Epoch 5/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3902 - accuracy: 0.8314
# Epoch 6/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3901 - accuracy: 0.8297
# Epoch 7/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3912 - accuracy: 0.8313
# Epoch 8/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3865 - accuracy: 0.8329
# Epoch 9/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3794 - accuracy: 0.8391
# Epoch 10/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3792 - accuracy: 0.8369
# Epoch 11/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3797 - accuracy: 0.8366
# Epoch 12/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3772 - accuracy: 0.8370
# Epoch 13/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3729 - accuracy: 0.8410
# Epoch 14/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3734 - accuracy: 0.8410
# Epoch 15/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3696 - accuracy: 0.8447
# Epoch 16/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3694 - accuracy: 0.8399
# Epoch 17/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3722 - accuracy: 0.8426
# Epoch 18/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3652 - accuracy: 0.8451
# Epoch 19/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3704 - accuracy: 0.8439
# Epoch 20/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3624 - accuracy: 0.8444
# Epoch 21/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3642 - accuracy: 0.8407
# Epoch 22/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3604 - accuracy: 0.8483
# Epoch 23/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3579 - accuracy: 0.8464
# Epoch 24/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3624 - accuracy: 0.8427
# Epoch 25/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3570 - accuracy: 0.8464
# Epoch 26/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3545 - accuracy: 0.8460
# Epoch 27/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3550 - accuracy: 0.8463
# Epoch 28/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3541 - accuracy: 0.8461
# Epoch 29/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3502 - accuracy: 0.8471
# Epoch 30/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3500 - accuracy: 0.8477
# Epoch 31/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3485 - accuracy: 0.8477
# Epoch 32/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3466 - accuracy: 0.8503
# Epoch 33/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3477 - accuracy: 0.8460
# Epoch 34/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3449 - accuracy: 0.8489
# Epoch 35/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3407 - accuracy: 0.8529
# Epoch 36/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3386 - accuracy: 0.8481
# Epoch 37/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3367 - accuracy: 0.8517
# Epoch 38/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3379 - accuracy: 0.8519
# Epoch 39/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3361 - accuracy: 0.8521
# Epoch 40/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3353 - accuracy: 0.8554
# Epoch 41/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3306 - accuracy: 0.8516
# Epoch 42/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3304 - accuracy: 0.8530
# Epoch 43/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3284 - accuracy: 0.8519
# Epoch 44/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3284 - accuracy: 0.8521
# Epoch 45/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3258 - accuracy: 0.8514
# Epoch 46/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3258 - accuracy: 0.8527
# Epoch 47/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3186 - accuracy: 0.8574
# Epoch 48/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3208 - accuracy: 0.8526
# Epoch 49/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3179 - accuracy: 0.8556
# Epoch 50/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3189 - accuracy: 0.8544
# Epoch 51/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3152 - accuracy: 0.8560
# Epoch 52/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3120 - accuracy: 0.8530
# Epoch 53/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3137 - accuracy: 0.8531
# Epoch 54/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.3147 - accuracy: 0.8539
# Epoch 55/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3082 - accuracy: 0.8563
# Epoch 56/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3099 - accuracy: 0.8536
# Epoch 57/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3031 - accuracy: 0.8580
# Epoch 58/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3025 - accuracy: 0.8600
# Epoch 59/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2989 - accuracy: 0.8597
# Epoch 60/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2989 - accuracy: 0.8591
# Epoch 61/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2988 - accuracy: 0.8577
# Epoch 62/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2934 - accuracy: 0.8606
# Epoch 63/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2949 - accuracy: 0.8574
# Epoch 64/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2939 - accuracy: 0.8586
# Epoch 65/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2941 - accuracy: 0.8570
# Epoch 66/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2928 - accuracy: 0.8566
# Epoch 67/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2878 - accuracy: 0.8584
# Epoch 68/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2821 - accuracy: 0.8649
# Epoch 69/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2839 - accuracy: 0.8616
# Epoch 70/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2839 - accuracy: 0.8626
# Epoch 71/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2784 - accuracy: 0.8611
# Epoch 72/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2780 - accuracy: 0.8627
# Epoch 73/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2817 - accuracy: 0.8630
# Epoch 74/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2772 - accuracy: 0.8629
# Epoch 75/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2783 - accuracy: 0.8614
# Epoch 76/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2739 - accuracy: 0.8634
# Epoch 77/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2717 - accuracy: 0.8631
# Epoch 78/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2674 - accuracy: 0.8631
# Epoch 79/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2708 - accuracy: 0.8637
# Epoch 80/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2623 - accuracy: 0.8626
# Epoch 81/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2704 - accuracy: 0.8644
# Epoch 82/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2651 - accuracy: 0.8621
# Epoch 83/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2637 - accuracy: 0.8641
# Epoch 84/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2543 - accuracy: 0.8683
# Epoch 85/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2652 - accuracy: 0.8641
# Epoch 86/100
# 219/219 [==============================] - 1s 5ms/step - loss: 0.2552 - accuracy: 0.8647
# Epoch 87/100
# 219/219 [==============================] - 1s 4ms/step - loss: 0.2579 - accuracy: 0.8661
# Epoch 88/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2516 - accuracy: 0.8681
# Epoch 89/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2489 - accuracy: 0.8659
# Epoch 90/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2504 - accuracy: 0.8707
# Epoch 91/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2516 - accuracy: 0.8646
# Epoch 92/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2452 - accuracy: 0.8693
# Epoch 93/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2495 - accuracy: 0.8647
# Epoch 94/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2438 - accuracy: 0.8669
# Epoch 95/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2446 - accuracy: 0.8689
# Epoch 96/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2458 - accuracy: 0.8730
# Epoch 97/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2432 - accuracy: 0.8660
# Epoch 98/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2386 - accuracy: 0.8787
# Epoch 99/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2419 - accuracy: 0.8724
# Epoch 100/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.2347 - accuracy: 0.8793
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
modelo.evaluate(x=X_test, y=y_test)
# Out:
# 94/94 [==============================] - 0s 2ms/step - loss: 0.6167 - accuracy: 0.8200
# [0.6166563630104065, 0.8199999928474426]

# %%
prever = pd.read_csv('/content/Churn_prever.csv',sep=';')

# %%
previsao = modelo.predict(prever)
# Out:
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 6ms/step

# %%
previsao
# Out:
# array([[0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %% [markdown]
# # MLBOX

# %%
from mlbox.preprocessing import *
from mlbox.optimization import *
from mlbox.prediction import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-1687b7e945df> in <cell line: 1>()
# ----> 1 from mlbox.preprocessing import *
#       2 from mlbox.optimization import *
#       3 from mlbox.prediction import *
#
# ModuleNotFoundError: No module named 'mlbox'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
caminho = ['churn_treino.csv','Churn_teste.csv']
imp = Reader(sep=';')
dados = imp.train_test_split(caminho,'Exited')

# %%
rdrift = Drift_thresholder()
dados = rdrift.fit_transform(dados)

# %%
otimizador = Optimizer()

# %%
espaco = {
    
}

# %%
modelo = otimizador.optmizer(espaco,dados, max_evals=15)

# %%
previsor = Predictor()
previsor.firt_predict(modelo, dados)
